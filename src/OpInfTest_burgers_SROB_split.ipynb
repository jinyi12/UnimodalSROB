# %%
from OpInf import *
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize


from pathlib import Path
import json
import stiefel

import importlib
importlib.reload(stiefel)

from scipy.io import loadmat
from operators import ckron, ckron_indices

import scienceplots
plt.style.use(["science", "no-latex", "grid"])
# Out:
# check syl solve
# True
# here
# True
# 6.485467719456075e-14
# Use algebraic Stiefel log, metric alpha =  -0.0
# dist 3.7699111843077584
# NORM TEST1: 0.0
# NORM TEST2: 1.9082066655962127e-13
# NORM TEST3: 7.92681892347602e-15

# %%
import numpy as np

def ddt(X, dt, scheme):
    """
    Uses specified difference scheme to approximate dX/dt with uniform time spacing of size dt.
    
    Parameters:
    X (np.array): N-by-K data matrix where each column is the state at one time.
    dt (float): Time step.
    scheme (str): Specifies which scheme is used to approximate time derivative.
    
    Returns:
    tuple: Tuple containing:
        - np.array: N-by-M data matrix of state time derivatives.
        - np.array: M-by-1 vector of indices of state data in X.
    """
    
    N, K = X.shape

    if scheme in [1, 'FE']:  # Forward Euler integration
        dXdt = (X[:, 1:] - X[:, :-1]) / dt
        ind = np.arange(K - 1)
    elif scheme == 'BE':  # Backward Euler integration
        dXdt = (X[:, 1:] - X[:, :-1]) / dt
        ind = np.arange(1, K)
    elif scheme in [2, '2c']:  # 2nd order central differencing
        dXdt = (X[:, 2:] - X[:, :-2]) / (2 * dt)
        ind = np.arange(1, K - 1)
    elif scheme == '2imp':  # 2nd order backward differencing (implicit)
        dXdt = (3 * X[:, 2:] - 4 * X[:, 1:-1] + X[:, :-2]) / (2 * dt)
        ind = np.arange(2, K)
    elif scheme == '2ex':  # 2nd order forward differencing (explicit)
        dXdt = (-3 * X[:, :-2] + 4 * X[:, 1:-1] - X[:, 2:]) / (2 * dt)
        ind = np.arange(K - 2)
    elif scheme in [4, '4c']:  # 4th order central differencing
        dXdt = (X[:, :-4] - 8 * X[:, 1:-3] + 8 * X[:, 3:-1] - X[:, 4:]) / (12 * dt)
        ind = np.arange(2, K - 2)
    elif scheme == '4imp':  # 4th order backward differencing
        dXdt = (25 / 12 * X[:, 4:] - 4 * X[:, 3:-1] + 3 * X[:, 2:-2] - 4 / 3 * X[:, 1:-3] + 1 / 4 * X[:, :-4]) / dt
        ind = np.arange(4, K)
    elif scheme == '4ex':  # 4th order forward differencing
        dXdt = (-25 / 12 * X[:, :-4] + 4 * X[:, 1:-3] - 3 * X[:, 2:-2] + 4 / 3 * X[:, 3:-1] - 1 / 4 * X[:, 4:]) / dt
        ind = np.arange(K - 4)
    else:
        raise ValueError('Specified difference scheme not implemented')

    return dXdt, ind

# Note: Function calls are commented out to adhere to instructions. They should be uncommented for testing purposes.
# Example of function call (commented out):
# X = np.random.rand(10, 5)  # Example

# %%
import numpy as np
from scipy.optimize import least_squares


def polynomial_form(x, p):
    """Polynomial representation of the reduced state snapshot data."""
    return [x**degree for degree in range(2, p+1)]



def relative_error(S_exact, S_reconstructed, Sref):
    """Calculate the relative squared Frobenius-norm error."""
    return np.linalg.norm(S_exact - S_reconstructed, 'fro') / np.linalg.norm(S_exact - Sref, 'fro')



def representation_learning_obj(x, snapshot_index, Vr, Vbar, Xi, S, sref, p=2):
    """Objective function for the nonlinear regression problem in the alternating minimization approach."""
    return S[:, snapshot_index] - sref - (Vr @ x) - (Vbar @ Xi @ np.concatenate(polynomial_form(x, p), axis=0))



def alternating_minimization(S, Sref, num_snapshots, max_iter, tol, gamma, r, q, p, initial_Shat=None):
    """
    Performs alternating minimization to solve for Shat given the system parameters.
    
    :param S: The system snapshots.
    :param Sref: The reference state.
    :param num_snapshots: Number of snapshots in S.
    :param max_iter: Maximum number of iterations for the minimization process.
    :param tol: Tolerance for convergence criterion.
    :param initial_Shat: Initial guess for Shat.
    :param gamma: Regularization parameter.
    :param r: Rank for Vr.
    :param q: Rank for Vbar.
    :param p: Order of polynomial form.
    :return: Optimized Shat and the final energy.
    """

    sref = Sref[:, 0]
    nrg_old = 0
    print("***Starting alternating minimizations:")

    # Define additional functions required for optimization here
    # e.g., polynomial_form(x), representation_learning_obj(x), etc.
    
    U, _, _ = np.linalg.svd(S - Sref, full_matrices=False)
    Vr = U[:, :r]
    Vbar = U[:, r:r+q]
    
    # Initialize Shat and other variables
    if initial_Shat:
        Shat = initial_Shat
    
    else:
        Shat = Vr.T @ (S-Sref)          # represent data in POD coordinates
    
    Proj_error = S - Sref - (Vr @ Shat)
    Poly = np.concatenate(polynomial_form(Shat, p=p), axis=0)
    Xi = Vbar.T @ Proj_error @ Poly.T @ np.linalg.inv(Poly @ Poly.T + gamma * np.identity((p - 1)*r))
    
    for niter in range(max_iter):
        # Step 1 - Orthogonal Procrustes (update basis vectors)
        Um, _, Vm = np.linalg.svd((S - Sref) @ np.concatenate([Shat, Xi @ Poly]).T, full_matrices=False)
        Omega = Um @ Vm
        Vr, Vbar = Omega[:, :r], Omega[:, r:r+q]

        # Step 2 - Linear regression (update coefficient matrix)
        Proj_error = S - Sref - (Vr @ Shat)
        rhs = np.linalg.inv(Poly @ Poly.T + (gamma * np.identity((p - 1) * r)))
        Xi = Vbar.T @ Proj_error @ Poly.T @ rhs

        # Step 3 - Nonlinear regression (update reduced state representation)
        for snapshot in range(num_snapshots):
            
            # Shat[:, snapshot] = least_squares(lambda x: representation_learning_obj(x, snapshot, Vr, Vbar, Xi, S, sref, p=p), Shat[:, snapshot], ftol=1e-9).x
            Shat[:, snapshot] = least_squares(representation_learning_obj, Shat[:, snapshot], args=(snapshot, Vr, Vbar, Xi, S, sref, p), ftol=1e-9).x
        Poly = np.concatenate(polynomial_form(Shat, p=p), axis=0)

        # Evaluate convergence criterion
        energy = np.linalg.norm(Vr @ Shat + (Vbar @ Xi @ Poly), 'fro')**2 / np.linalg.norm(S - Sref, 'fro')**2
        diff = abs(energy - nrg_old)
        print(f"\titeration: {niter+1:d}\tsnapshot energy: {energy:e}\t diff: {diff:e}")
        if diff < tol:
            print("***Convergence criterion active!")
            break
        nrg_old = energy  # Update old energy metric

    return Shat, energy, Xi, Vr, Vbar, Poly

# To call this function, you would need to prepare all the required arguments first.
# For example:
# Shat_optimized, final_energy = alternating_minimization(S, Sref, num_snapshots, max_iter, tol, initial_Shat, gamma, r, q, p)

# %%
mus = [1.1, 1.05, 1, 0.95, 0.9]
# Load data
T_end_train = 2
dt= 1e-3
Train_T = int(T_end_train/dt)

X_all_nominal = np.load("../examples/burgers/burgersFEniCSx_u_sol_all_RE100.npy")[:, :Train_T+1, :]
X_all_p1per = np.load("../examples/burgers/burgersFEniCSx_u_sol_all_RE100_p1per.npy")[:, :Train_T+1, :]
X_all_n1per = np.load("../examples/burgers/burgersFEniCSx_u_sol_all_RE100_n1per.npy")[:, :Train_T+1, :]
X_all_p5per = np.load("../examples/burgers/burgersFEniCSx_u_sol_all_RE100_p5per.npy")[:, :Train_T+1, :]
X_all_n5per = np.load("../examples/burgers/burgersFEniCSx_u_sol_all_RE100_n5per.npy")[:, :Train_T+1, :]

# %%
p = 2
Mp = len(mus)
dt = 1e-3
T_end = 2

config = {
    "N": 2**7 + 1 + 1,
    "dt": 1e-3,
    "T_end": T_end,
    "mus": list(mus),
    "Mp": Mp,
    "K": T_end / dt,  # T_end / dt
    "DS": 1,
    "params": {
        "modelform": "LQCP",
        "modeltime": "continuous",
        "dt": dt,
        "ddt_order": "BE",
        "p": p, # polynomial order
        "lambda1": 5e-2,
        "lambda2": 5e-2,
        "lambda3": 100,
    },
    "type": "single"
}

# %%
X_all_nominal.shape
# Out:
# (5, 2001, 130)

# %%
X_nominal = np.concatenate([X for X in X_all_nominal], axis=0).T
X_p1per = np.concatenate([X for X in X_all_p1per], axis=0).T
X_n1per = np.concatenate([X for X in X_all_n1per], axis=0).T
X_p5per = np.concatenate([X for X in X_all_p5per], axis=0).T
X_n5per = np.concatenate([X for X in X_all_n5per], axis=0).T

# %%
X_list = [X_p1per, X_n1per, X_p5per, X_n5per, X_nominal]

# %%
rob_lst = []
rel_err_SVD_lst = []
idx_lst = []
names = [f'p1per RE100', f'n1per RE100', f'p5per RE100', f'n5per RE100', f'Nominal RE100']

fig, ax = plt.subplots(figsize=(6, 4.5))

err_tol = 5e-2

# mus = [0.01] # only one mu for now

for i in range(len(X_list)):
    
    X = X_list[i]
    
    # X_ref is the reference state which is just defined as the mean of the snapshots 
    X_ref = np.mean(X, axis=1)[:, None]
    
    print("X = ", X.shape)
    print("X_ref = ", X_ref.shape)
    
    # svd
    U, S, V = np.linalg.svd((X - X_ref), full_matrices=False)
    print("S = ", S[:5])
    eigvals_SVD = S**2 * (1 / (len(S) - 1))
    # print("eigvals_SVD = \n", eigvals_SVD[:5])
    # append U
    # print("U = ", U.shape)
    rob_lst.append(U)
    
    # calculate the relative error
    rel_err_SVD = 1 - (np.cumsum(eigvals_SVD) / np.sum(eigvals_SVD))
    rel_err_SVD_lst.append(rel_err_SVD)
    # print("rel_err_SVD = \n", rel_err_SVD[:4])

    # print the first idx when it is less than 1e-4
    idx = np.where(rel_err_SVD < err_tol)[0][0] + 1
    idx_lst.append(idx)
    print("idx = ", idx)
    print("rel_err_SVD[idx] = ", rel_err_SVD[idx])
    
    ax.plot(rel_err_SVD_lst[i], label=names[i], linestyle='-', alpha=0.7)
    ax.plot(idx, rel_err_SVD[idx], 'ro', label=f"{err_tol:.2e} at r={idx}, {names[i]}")
    ax.set_yscale('log')
    ax.set_ylabel("$\epsilon$ (log scale)")
    # set limit
    ax.set_xlim([0, 200])
    # ax.set_ylim([1e-13, 1e-3])
    # show grid
    ax.grid(True, alpha=0.2)
    ax.set_xlabel("Rank r")
    ax.set_title("Relative error, Nominal RE100")
    ax.legend()
# Out:
# X =  (130, 10005)
# X_ref =  (130, 1)
# S =  [182.61019219 103.96051164  59.44319585  40.44800931  27.79984476]
# idx =  4
# rel_err_SVD[idx] =  0.01848015895214028
# X =  (130, 10005)
# X_ref =  (130, 1)
# S =  [182.25557676 103.5489728   58.99784923  40.05590471  27.55403553]
# idx =  4
# rel_err_SVD[idx] =  0.01781305529785715
# X =  (130, 10005)
# X_ref =  (130, 1)
# S =  [183.27411586 104.73054211  60.28233983  41.19952589  28.27831031]
# idx =  4
# rel_err_SVD[idx] =  0.019800034385545007
# X =  (130, 10005)
# X_ref =  (130, 1)
# S =  [181.49609979 102.66738996  58.05145524  39.23856595  27.046048  ]
# idx =  4
# rel_err_SVD[idx] =  0.01646768888534933
# X =  (130, 10005)
# X_ref =  (130, 1)
# S =  [182.43487026 103.75706142  59.2227547   40.25333123  27.67754859]
# idx =  4
# rel_err_SVD[idx] =  0.018147143202631888

# %%
np.max(idx_lst)
# Out:
# 4

# %%
# Model parameters
r = np.max(idx_lst)
q_trunc = 2
# p = 3

tol = 1e-3      # tolerence for alternating minimization
gamma = 0.1       # regularization parameter
max_iter = 100  # maximum number of iterations

Vr_lst = []
Vbar_lst = []
Shat_lst = []
Xi_lst = []
Poly_lst = []

for i in range(len(X_list)):
    # Procustes problem for each mu
    X = X_list[i]
    num_snapshots = X.shape[1]
    print("num_snapshots: ", num_snapshots)
    print("X = ", X.shape)
    # X_ref = np.mean(X, axis=1)[:, None]
    X_ref = np.zeros((X.shape[0]))[:, None]
    X_centered = X - X_ref

    U, S, Vr = np.linalg.svd(X_centered, full_matrices=False)
    
    Vr = U[:, :r]
    Vbar = U[:, r:r + q_trunc]
    q = Vr.T @ X_centered
    Proj_error = X_centered - (Vr @ q)
    Poly = np.concatenate(polynomial_form(q, p), axis=0)
    Xi = Vbar.T @ Proj_error @ Poly.T @ np.linalg.inv(Poly @ Poly.T + gamma * np.identity((p - 1)*r))
    
    energy = np.linalg.norm(Vr @ q + (Vbar @ Xi @ Poly), 'fro')**2 / np.linalg.norm(X - X_ref, 'fro')**2
    
    print(f"Snapshot energy: {energy:e}")

    Gamma_MPOD = X_ref + (Vr @ q) + (Vbar @ Xi @ Poly)
    print(f"\nReconstruction error: {relative_error(X, Gamma_MPOD, X_ref):.4%}")
    
    Vr_lst.append(Vr)
    Vbar_lst.append(Vbar)
    Shat_lst.append(q)
    Xi_lst.append(Xi)
    Poly_lst.append(Poly)

    # q, energy, Xi, Vr, Vbar, Poly = alternating_minimization(X, X_ref, num_snapshots, max_iter, 1e-3, gamma, r, q, p, initial_Shat=None)

    # print("q = ", q.shape)
    # print("qbar = ", qbar.shape)
# Out:
# num_snapshots:  10005
# X =  (130, 10005)
# Snapshot energy: 9.932022e-01
#
# Reconstruction error: 8.2447%
# num_snapshots:  10005
# X =  (130, 10005)
# Snapshot energy: 9.934573e-01
#
# Reconstruction error: 8.0885%
# num_snapshots:  10005
# X =  (130, 10005)
# Snapshot energy: 9.926919e-01
#
# Reconstruction error: 8.5486%
# num_snapshots:  10005
# X =  (130, 10005)
# Snapshot energy: 9.939662e-01
#
# Reconstruction error: 7.7676%
# num_snapshots:  10005
# X =  (130, 10005)
# Snapshot energy: 9.933298e-01
#
# Reconstruction error: 8.1669%

# %%
Gamma_MPOD = X_ref + (Vr @ q) + (Vbar @ Xi @ Poly)
print(f"\nReconstruction error: {relative_error(X, Gamma_MPOD, X_ref):.4%}")
# Out:
# Reconstruction error: 8.1669%

# %%
# Get nominal Reynolds for OpInf
X = X_list[-1][:, ]

# %%
Mp = len(mus)
Nsnapshots = X.shape[1]
dShatdt = []
Shat_lst = []
dSdt = []
for j in range(Mp):
    start_ind = int((j) * Nsnapshots/Mp)
    end_ind = int((j+1) * Nsnapshots/Mp)
    print("start_ind: ", start_ind)
    print("end_ind: ", end_ind)
    ddtshat, ind = ddt(q[:, start_ind:end_ind], dt=dt, scheme='BE')
    ddts, ind = ddt(X[:, start_ind:end_ind], dt=dt, scheme="BE")
    dShatdt.append(ddtshat)
    ind = np.array(ind) + int((j) * Nsnapshots/Mp)
    Shat_lst.append(q[:, ind])
    dSdt.append(ddts)
# Out:
# start_ind:  0
# end_ind:  2001
# start_ind:  2001
# end_ind:  4002
# start_ind:  4002
# end_ind:  6003
# start_ind:  6003
# end_ind:  8004
# start_ind:  8004
# end_ind:  10005

# %%
import importlib
import OpInf
# import reloading
# reload the whole OpInf module
importlib.reload(OpInf)
from OpInf import *

# %%
def initial_condition(coord):
    if coord <= 0.5:
        return np.sin(2 * np.pi * coord)
    
    return 0

# update config file with truncation order r
config['robparams'] = {
    "r": int(r)
}

Shat_py = np.concatenate(Shat_lst, axis=1)
dShatdt_py = np.concatenate(dShatdt, axis=1).T
dSdt_py = np.hstack(dSdt)

print("Shape of Shat_py: ", Shat_py.shape)
print("Shape of dShatdt_py: ", dShatdt_py.shape)
# [operators] = inferOperators_NL(Shat, U, params, dShatdt);

operators = infer_operators_nl(Shat_py, None, config['params'], dShatdt_py)
# operators = infer_operators_nl(q, None, config['params'], /dShatdt_py)
# Out:
# Shape of Shat_py:  (4, 10000)
# Shape of dShatdt_py:  (10000, 4)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.05 0.05 100
# Solving...
# Solved!

# %%
config['robparams'] = {
    "r": int(r)
}

N = int(config['N'])
dt = config['dt']
T_end = config['T_end']
mus = config['mus']  # Assuming mus is saved as a string that represents a Python expression
Mp = config['Mp']
K = int(config['K'])
DS = config['DS']
params = config['params']  # This will be a dictionary in Python
robparams = config['robparams']  # This will be a dictionary in Python


coord = np.linspace(0, 1, N)
print("coord = ", coord.shape)
IC = np.array([initial_condition(c) for c in coord])
q0 = Vr.T @ (IC[:, None] - X_ref).flatten()
time_domain = np.arange(0, T_end, dt)
train_size = Shat_py.shape[1]

# regs = [1e1, 3e3, 1e9]
# regs = [0.001, 20, 1e5]
Shat_true = Shat_lst[2]
regs_product = [1e-3, 1e1, 3, 1e1, 1e4, 10, 1e1, 1e7, 7]
# regs_product = [1e-3, 1e-3, 1, 23, 60, 10]
# regs_product = [1e-3, 1e-2, 5, 1e-3, 1e-2, 5, 1e-3, 1e-1, 5]
# regs, operators = train_minimize(Shat_py, dShatdt_py, Shat_true, train_size, r, regs, time_domain, q0, params, testsize=None, margin=1.1)
regs, errors = train_gridsearch(Shat_py, dShatdt_py, Shat_true, train_size, r, regs_product, time_domain, q0, params, testsize=None, margin=1.1)
# Out:
# coord =  (130,)
# Constructing least-squares solver, r=4
# TRAINING 210 ROMS
# (1/210) Testing ROM with (0.001, 10.0, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 10.0 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (2/210) Testing ROM with (0.001, 10.0, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 10.0 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (3/210) Testing ROM with (0.001, 10.0, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 10.0 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (4/210) Testing ROM with (0.001, 10.0, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 10.0 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (5/210) Testing ROM with (0.001, 10.0, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 10.0 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (6/210) Testing ROM with (0.001, 10.0, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 10.0 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (7/210) Testing ROM with (0.001, 10.0, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 10.0 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (8/210) Testing ROM with (0.001, 21.544346900318832, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 21.544346900318832 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (9/210) Testing ROM with (0.001, 21.544346900318832, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 21.544346900318832 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (10/210) Testing ROM with (0.001, 21.544346900318832, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 21.544346900318832 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (11/210) Testing ROM with (0.001, 21.544346900318832, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 21.544346900318832 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (12/210) Testing ROM with (0.001, 21.544346900318832, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 21.544346900318832 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (13/210) Testing ROM with (0.001, 21.544346900318832, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 21.544346900318832 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (14/210) Testing ROM with (0.001, 21.544346900318832, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 21.544346900318832 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (15/210) Testing ROM with (0.001, 46.41588833612778, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 46.41588833612778 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (16/210) Testing ROM with (0.001, 46.41588833612778, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 46.41588833612778 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (17/210) Testing ROM with (0.001, 46.41588833612778, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 46.41588833612778 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (18/210) Testing ROM with (0.001, 46.41588833612778, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 46.41588833612778 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (19/210) Testing ROM with (0.001, 46.41588833612778, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 46.41588833612778 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (20/210) Testing ROM with (0.001, 46.41588833612778, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 46.41588833612778 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (21/210) Testing ROM with (0.001, 46.41588833612778, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 46.41588833612778 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (22/210) Testing ROM with (0.001, 100.0, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 100.0 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (23/210) Testing ROM with (0.001, 100.0, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 100.0 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (24/210) Testing ROM with (0.001, 100.0, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 100.0 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (25/210) Testing ROM with (0.001, 100.0, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 100.0 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (26/210) Testing ROM with (0.001, 100.0, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 100.0 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (27/210) Testing ROM with (0.001, 100.0, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 100.0 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (28/210) Testing ROM with (0.001, 100.0, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 100.0 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (29/210) Testing ROM with (0.001, 215.44346900318823, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 215.44346900318823 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (30/210) Testing ROM with (0.001, 215.44346900318823, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 215.44346900318823 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (31/210) Testing ROM with (0.001, 215.44346900318823, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 215.44346900318823 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (32/210) Testing ROM with (0.001, 215.44346900318823, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 215.44346900318823 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (33/210) Testing ROM with (0.001, 215.44346900318823, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 215.44346900318823 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (34/210) Testing ROM with (0.001, 215.44346900318823, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 215.44346900318823 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (35/210) Testing ROM with (0.001, 215.44346900318823, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 215.44346900318823 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (36/210) Testing ROM with (0.001, 464.15888336127773, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 464.15888336127773 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (37/210) Testing ROM with (0.001, 464.15888336127773, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 464.15888336127773 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (38/210) Testing ROM with (0.001, 464.15888336127773, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 464.15888336127773 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (39/210) Testing ROM with (0.001, 464.15888336127773, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 464.15888336127773 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (40/210) Testing ROM with (0.001, 464.15888336127773, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 464.15888336127773 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (41/210) Testing ROM with (0.001, 464.15888336127773, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 464.15888336127773 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (42/210) Testing ROM with (0.001, 464.15888336127773, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 464.15888336127773 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (43/210) Testing ROM with (0.001, 1000.0, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 1000.0 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (44/210) Testing ROM with (0.001, 1000.0, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 1000.0 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (45/210) Testing ROM with (0.001, 1000.0, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 1000.0 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (46/210) Testing ROM with (0.001, 1000.0, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 1000.0 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (47/210) Testing ROM with (0.001, 1000.0, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 1000.0 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (48/210) Testing ROM with (0.001, 1000.0, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 1000.0 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (49/210) Testing ROM with (0.001, 1000.0, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 1000.0 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (50/210) Testing ROM with (0.001, 2154.434690031882, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 2154.434690031882 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (51/210) Testing ROM with (0.001, 2154.434690031882, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 2154.434690031882 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (52/210) Testing ROM with (0.001, 2154.434690031882, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 2154.434690031882 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (53/210) Testing ROM with (0.001, 2154.434690031882, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 2154.434690031882 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (54/210) Testing ROM with (0.001, 2154.434690031882, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 2154.434690031882 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (55/210) Testing ROM with (0.001, 2154.434690031882, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 2154.434690031882 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (56/210) Testing ROM with (0.001, 2154.434690031882, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 2154.434690031882 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (57/210) Testing ROM with (0.001, 4641.588833612777, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 4641.588833612777 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (58/210) Testing ROM with (0.001, 4641.588833612777, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 4641.588833612777 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (59/210) Testing ROM with (0.001, 4641.588833612777, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 4641.588833612777 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (60/210) Testing ROM with (0.001, 4641.588833612777, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 4641.588833612777 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (61/210) Testing ROM with (0.001, 4641.588833612777, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 4641.588833612777 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (62/210) Testing ROM with (0.001, 4641.588833612777, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 4641.588833612777 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (63/210) Testing ROM with (0.001, 4641.588833612777, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 4641.588833612777 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (64/210) Testing ROM with (0.001, 10000.0, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 10000.0 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (65/210) Testing ROM with (0.001, 10000.0, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 10000.0 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (66/210) Testing ROM with (0.001, 10000.0, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 10000.0 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (67/210) Testing ROM with (0.001, 10000.0, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 10000.0 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (68/210) Testing ROM with (0.001, 10000.0, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 10000.0 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (69/210) Testing ROM with (0.001, 10000.0, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 10000.0 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (70/210) Testing ROM with (0.001, 10000.0, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.001 10000.0 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (71/210) Testing ROM with (0.09999999999999999, 10.0, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 10.0 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (72/210) Testing ROM with (0.09999999999999999, 10.0, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 10.0 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (73/210) Testing ROM with (0.09999999999999999, 10.0, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 10.0 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (74/210) Testing ROM with (0.09999999999999999, 10.0, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 10.0 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (75/210) Testing ROM with (0.09999999999999999, 10.0, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 10.0 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (76/210) Testing ROM with (0.09999999999999999, 10.0, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 10.0 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (77/210) Testing ROM with (0.09999999999999999, 10.0, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 10.0 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (78/210) Testing ROM with (0.09999999999999999, 21.544346900318832, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 21.544346900318832 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (79/210) Testing ROM with (0.09999999999999999, 21.544346900318832, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 21.544346900318832 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (80/210) Testing ROM with (0.09999999999999999, 21.544346900318832, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 21.544346900318832 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (81/210) Testing ROM with (0.09999999999999999, 21.544346900318832, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 21.544346900318832 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (82/210) Testing ROM with (0.09999999999999999, 21.544346900318832, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 21.544346900318832 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (83/210) Testing ROM with (0.09999999999999999, 21.544346900318832, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 21.544346900318832 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (84/210) Testing ROM with (0.09999999999999999, 21.544346900318832, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 21.544346900318832 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (85/210) Testing ROM with (0.09999999999999999, 46.41588833612778, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 46.41588833612778 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (86/210) Testing ROM with (0.09999999999999999, 46.41588833612778, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 46.41588833612778 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (87/210) Testing ROM with (0.09999999999999999, 46.41588833612778, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 46.41588833612778 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (88/210) Testing ROM with (0.09999999999999999, 46.41588833612778, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 46.41588833612778 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (89/210) Testing ROM with (0.09999999999999999, 46.41588833612778, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 46.41588833612778 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (90/210) Testing ROM with (0.09999999999999999, 46.41588833612778, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 46.41588833612778 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (91/210) Testing ROM with (0.09999999999999999, 46.41588833612778, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 46.41588833612778 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (92/210) Testing ROM with (0.09999999999999999, 100.0, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 100.0 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (93/210) Testing ROM with (0.09999999999999999, 100.0, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 100.0 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (94/210) Testing ROM with (0.09999999999999999, 100.0, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 100.0 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (95/210) Testing ROM with (0.09999999999999999, 100.0, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 100.0 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (96/210) Testing ROM with (0.09999999999999999, 100.0, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 100.0 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (97/210) Testing ROM with (0.09999999999999999, 100.0, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 100.0 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (98/210) Testing ROM with (0.09999999999999999, 100.0, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 100.0 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (99/210) Testing ROM with (0.09999999999999999, 215.44346900318823, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 215.44346900318823 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (100/210) Testing ROM with (0.09999999999999999, 215.44346900318823, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 215.44346900318823 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (101/210) Testing ROM with (0.09999999999999999, 215.44346900318823, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 215.44346900318823 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (102/210) Testing ROM with (0.09999999999999999, 215.44346900318823, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 215.44346900318823 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (103/210) Testing ROM with (0.09999999999999999, 215.44346900318823, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 215.44346900318823 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (104/210) Testing ROM with (0.09999999999999999, 215.44346900318823, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 215.44346900318823 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (105/210) Testing ROM with (0.09999999999999999, 215.44346900318823, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 215.44346900318823 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (106/210) Testing ROM with (0.09999999999999999, 464.15888336127773, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 464.15888336127773 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (107/210) Testing ROM with (0.09999999999999999, 464.15888336127773, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 464.15888336127773 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (108/210) Testing ROM with (0.09999999999999999, 464.15888336127773, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 464.15888336127773 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (109/210) Testing ROM with (0.09999999999999999, 464.15888336127773, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 464.15888336127773 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (110/210) Testing ROM with (0.09999999999999999, 464.15888336127773, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 464.15888336127773 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (111/210) Testing ROM with (0.09999999999999999, 464.15888336127773, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 464.15888336127773 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (112/210) Testing ROM with (0.09999999999999999, 464.15888336127773, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 464.15888336127773 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (113/210) Testing ROM with (0.09999999999999999, 1000.0, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 1000.0 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (114/210) Testing ROM with (0.09999999999999999, 1000.0, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 1000.0 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (115/210) Testing ROM with (0.09999999999999999, 1000.0, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 1000.0 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (116/210) Testing ROM with (0.09999999999999999, 1000.0, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 1000.0 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (117/210) Testing ROM with (0.09999999999999999, 1000.0, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 1000.0 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (118/210) Testing ROM with (0.09999999999999999, 1000.0, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 1000.0 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (119/210) Testing ROM with (0.09999999999999999, 1000.0, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 1000.0 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (120/210) Testing ROM with (0.09999999999999999, 2154.434690031882, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 2154.434690031882 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (121/210) Testing ROM with (0.09999999999999999, 2154.434690031882, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 2154.434690031882 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (122/210) Testing ROM with (0.09999999999999999, 2154.434690031882, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 2154.434690031882 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (123/210) Testing ROM with (0.09999999999999999, 2154.434690031882, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 2154.434690031882 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (124/210) Testing ROM with (0.09999999999999999, 2154.434690031882, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 2154.434690031882 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (125/210) Testing ROM with (0.09999999999999999, 2154.434690031882, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 2154.434690031882 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (126/210) Testing ROM with (0.09999999999999999, 2154.434690031882, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 2154.434690031882 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (127/210) Testing ROM with (0.09999999999999999, 4641.588833612777, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 4641.588833612777 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (128/210) Testing ROM with (0.09999999999999999, 4641.588833612777, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 4641.588833612777 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (129/210) Testing ROM with (0.09999999999999999, 4641.588833612777, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 4641.588833612777 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (130/210) Testing ROM with (0.09999999999999999, 4641.588833612777, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 4641.588833612777 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (131/210) Testing ROM with (0.09999999999999999, 4641.588833612777, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 4641.588833612777 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (132/210) Testing ROM with (0.09999999999999999, 4641.588833612777, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 4641.588833612777 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (133/210) Testing ROM with (0.09999999999999999, 4641.588833612777, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 4641.588833612777 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (134/210) Testing ROM with (0.09999999999999999, 10000.0, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 10000.0 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (135/210) Testing ROM with (0.09999999999999999, 10000.0, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 10000.0 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (136/210) Testing ROM with (0.09999999999999999, 10000.0, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 10000.0 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (137/210) Testing ROM with (0.09999999999999999, 10000.0, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 10000.0 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (138/210) Testing ROM with (0.09999999999999999, 10000.0, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 10000.0 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (139/210) Testing ROM with (0.09999999999999999, 10000.0, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 10000.0 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (140/210) Testing ROM with (0.09999999999999999, 10000.0, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  0.09999999999999999 10000.0 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (141/210) Testing ROM with (10.0, 10.0, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 10.0 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (142/210) Testing ROM with (10.0, 10.0, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 10.0 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (143/210) Testing ROM with (10.0, 10.0, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 10.0 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (144/210) Testing ROM with (10.0, 10.0, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 10.0 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (145/210) Testing ROM with (10.0, 10.0, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 10.0 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (146/210) Testing ROM with (10.0, 10.0, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 10.0 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (147/210) Testing ROM with (10.0, 10.0, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 10.0 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (148/210) Testing ROM with (10.0, 21.544346900318832, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 21.544346900318832 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (149/210) Testing ROM with (10.0, 21.544346900318832, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 21.544346900318832 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (150/210) Testing ROM with (10.0, 21.544346900318832, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 21.544346900318832 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (151/210) Testing ROM with (10.0, 21.544346900318832, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 21.544346900318832 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (152/210) Testing ROM with (10.0, 21.544346900318832, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 21.544346900318832 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (153/210) Testing ROM with (10.0, 21.544346900318832, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 21.544346900318832 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (154/210) Testing ROM with (10.0, 21.544346900318832, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 21.544346900318832 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (155/210) Testing ROM with (10.0, 46.41588833612778, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 46.41588833612778 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (156/210) Testing ROM with (10.0, 46.41588833612778, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 46.41588833612778 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (157/210) Testing ROM with (10.0, 46.41588833612778, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 46.41588833612778 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (158/210) Testing ROM with (10.0, 46.41588833612778, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 46.41588833612778 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (159/210) Testing ROM with (10.0, 46.41588833612778, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 46.41588833612778 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (160/210) Testing ROM with (10.0, 46.41588833612778, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 46.41588833612778 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (161/210) Testing ROM with (10.0, 46.41588833612778, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 46.41588833612778 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (162/210) Testing ROM with (10.0, 100.0, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 100.0 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (163/210) Testing ROM with (10.0, 100.0, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 100.0 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (164/210) Testing ROM with (10.0, 100.0, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 100.0 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (165/210) Testing ROM with (10.0, 100.0, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 100.0 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (166/210) Testing ROM with (10.0, 100.0, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 100.0 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (167/210) Testing ROM with (10.0, 100.0, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 100.0 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (168/210) Testing ROM with (10.0, 100.0, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 100.0 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (169/210) Testing ROM with (10.0, 215.44346900318823, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 215.44346900318823 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (170/210) Testing ROM with (10.0, 215.44346900318823, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 215.44346900318823 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (171/210) Testing ROM with (10.0, 215.44346900318823, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 215.44346900318823 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (172/210) Testing ROM with (10.0, 215.44346900318823, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 215.44346900318823 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (173/210) Testing ROM with (10.0, 215.44346900318823, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 215.44346900318823 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (174/210) Testing ROM with (10.0, 215.44346900318823, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 215.44346900318823 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (175/210) Testing ROM with (10.0, 215.44346900318823, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 215.44346900318823 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (176/210) Testing ROM with (10.0, 464.15888336127773, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 464.15888336127773 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (177/210) Testing ROM with (10.0, 464.15888336127773, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 464.15888336127773 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (178/210) Testing ROM with (10.0, 464.15888336127773, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 464.15888336127773 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (179/210) Testing ROM with (10.0, 464.15888336127773, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 464.15888336127773 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (180/210) Testing ROM with (10.0, 464.15888336127773, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 464.15888336127773 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (181/210) Testing ROM with (10.0, 464.15888336127773, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 464.15888336127773 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (182/210) Testing ROM with (10.0, 464.15888336127773, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 464.15888336127773 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (183/210) Testing ROM with (10.0, 1000.0, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 1000.0 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (184/210) Testing ROM with (10.0, 1000.0, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 1000.0 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (185/210) Testing ROM with (10.0, 1000.0, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 1000.0 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (186/210) Testing ROM with (10.0, 1000.0, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 1000.0 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (187/210) Testing ROM with (10.0, 1000.0, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 1000.0 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (188/210) Testing ROM with (10.0, 1000.0, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 1000.0 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (189/210) Testing ROM with (10.0, 1000.0, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 1000.0 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (190/210) Testing ROM with (10.0, 2154.434690031882, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 2154.434690031882 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (191/210) Testing ROM with (10.0, 2154.434690031882, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 2154.434690031882 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (192/210) Testing ROM with (10.0, 2154.434690031882, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 2154.434690031882 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (193/210) Testing ROM with (10.0, 2154.434690031882, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 2154.434690031882 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (194/210) Testing ROM with (10.0, 2154.434690031882, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 2154.434690031882 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (195/210) Testing ROM with (10.0, 2154.434690031882, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 2154.434690031882 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (196/210) Testing ROM with (10.0, 2154.434690031882, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 2154.434690031882 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (197/210) Testing ROM with (10.0, 4641.588833612777, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 4641.588833612777 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (198/210) Testing ROM with (10.0, 4641.588833612777, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 4641.588833612777 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (199/210) Testing ROM with (10.0, 4641.588833612777, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 4641.588833612777 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (200/210) Testing ROM with (10.0, 4641.588833612777, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 4641.588833612777 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (201/210) Testing ROM with (10.0, 4641.588833612777, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 4641.588833612777 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (202/210) Testing ROM with (10.0, 4641.588833612777, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 4641.588833612777 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (203/210) Testing ROM with (10.0, 4641.588833612777, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 4641.588833612777 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (204/210) Testing ROM with (10.0, 10000.0, 10.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 10000.0 10.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (205/210) Testing ROM with (10.0, 10000.0, 100.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 10000.0 100.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (206/210) Testing ROM with (10.0, 10000.0, 1000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 10000.0 1000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (207/210) Testing ROM with (10.0, 10000.0, 10000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 10000.0 10000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (208/210) Testing ROM with (10.0, 10000.0, 100000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 10000.0 100000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (209/210) Testing ROM with (10.0, 10000.0, 1000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 10000.0 1000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed
# (210/210) Testing ROM with (10.0, 10000.0, 10000000.0)
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 10000.0 10000000.0
# Solving...
# Solved!
# Integrating...
# Bound check passed

# %%
print("Errors:, ", errors)
print("regs: ", regs)
# Out:
# Errors:,  0.003089251778269283
# regs:  [10.0, 10.0, 10.0]

# %%
# regs = [0.0005399173326341194, 23.61197176062329, 202651972.5062846]

params['lambda1'] = regs[0]
params['lambda2'] = regs[1]
if len(regs) > 2:
    params['lambda3'] = regs[2]

# params['lambda1'] = (5e-2)**2
# params['lambda2'] = (5e-2)**2
# if len(regs) > 2:
#     params['lambda3'] = regs[2]
operators = infer_operators_nl(Shat_py, None, config['params'], dShatdt_py)
# Out:
# Generating ghat ...
# drp:  26
# Obtained data matrix...
# Regularization parameters:  10.0 10.0 10.0
# Solving...
# Solved!

# %%
from stiefel import *
import importlib
importlib.reload(stiefel)
N_stiefel_samples = 1000

V_combined_lst = [np.concatenate([Vr, Vbar], axis=1) for Vr, Vbar in zip(Vr_lst, Vbar_lst)]

# Generate the samples and split them into two arrays
stiefel_samples_combined = stiefel.gen_stiefel_samples(N_stiefel_samples, V_combined_lst, tau=0.00001, metric_alpha=0.0000000000000)
stiefel_samples_Vr = [sample[:, :r] for sample in stiefel_samples_combined]
stiefel_samples_Vbar = [sample[:, r:r+q_trunc] for sample in stiefel_samples_combined]
# Out:
# Use algebraic Stiefel log, metric alpha =  0.0
# Use algebraic Stiefel log, metric alpha =  0.0
# Use algebraic Stiefel log, metric alpha =  0.0
# Use algebraic Stiefel log, metric alpha =  0.0
# Use algebraic Stiefel log, metric alpha =  0.0
# ===============================================================================
#                                      CVXPY
#                                      v1.4.2
# ===============================================================================
# (CVXPY) Apr 30 01:39:42 PM: Your problem has 4 variables, 3 constraints, and 0 parameters.
# (CVXPY) Apr 30 01:39:42 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 30 01:39:42 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 30 01:39:42 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Apr 30 01:39:42 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 30 01:39:42 PM: Compiling problem (target solver=OSQP).
# (CVXPY) Apr 30 01:39:42 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Apr 30 01:39:42 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 30 01:39:42 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Apr 30 01:39:42 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Apr 30 01:39:42 PM: Applying reduction OSQP
# (CVXPY) Apr 30 01:39:42 PM: Finished problem compilation (took 3.026e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 30 01:39:42 PM: Invoking solver OSQP  to obtain a solution.
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 4, constraints m = 9
#           nnz(P) + nnz(A) = 22
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-10, eps_rel = 1.0e-10,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.00e+00   1.00e+02   1.00e-01   2.48e-05s
#  200   4.6838e-10   1.29e-03   6.45e-10   1.00e-06   5.54e-05s
#  400   4.7533e-10   2.14e-04   8.40e-10   1.00e-06   8.38e-05s
#  600   4.7750e-10   2.00e-04   1.89e-10   1.00e-06   1.10e-04s
#  800   4.7652e-10   5.55e-05   1.25e-10   1.00e-06   1.36e-04s
# 1000   4.7605e-10   2.88e-05   4.42e-11   1.00e-06   1.62e-04s
# 1200   4.7618e-10   1.22e-05   1.72e-11   1.00e-06   1.87e-04s
# 1400   4.7627e-10   3.75e-06   9.16e-12   1.00e-06   2.13e-04s
# 1600   4.7626e-10   2.44e-06   2.05e-12   1.00e-06   2.38e-04s
# 1800   4.7624e-10   4.08e-07   1.76e-12   1.00e-06   2.63e-04s
# 2000   4.7624e-10   4.54e-07   1.83e-13   1.00e-06   2.90e-04s
# 2200   4.7624e-10   2.64e-08   3.17e-13   1.00e-06   3.15e-04s
# 2400   4.7624e-10   7.99e-08   1.09e-15   1.00e-06   3.41e-04s
# 2600   4.7624e-10   3.89e-09   5.41e-14   1.00e-06   3.67e-04s
# 2800   4.7624e-10   1.33e-08   5.02e-15   1.00e-06   3.92e-04s
# 3000   4.7624e-10   1.81e-09   8.75e-15   1.00e-06   4.18e-04s
# 3050   4.7624e-10   1.78e-10   7.44e-15   1.00e-06   4.29e-04s
# plsh   4.7624e-10   3.40e-19   2.74e-16   --------   4.40e-04s
#
# status:               solved
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 30 01:39:42 PM: Problem status: optimal
# solution polish:      successful
# number of iterations: 3050
# optimal objective:    0.0000
# run time:             4.40e-04s
# optimal rho estimate: 1.00e-06
#
# (CVXPY) Apr 30 01:39:42 PM: Optimal value: 4.762e-10
# (CVXPY) Apr 30 01:39:42 PM: Compilation took 3.026e-03 seconds
# (CVXPY) Apr 30 01:39:42 PM: Solver (including time spent in interface) took 1.090e-03 seconds
# beta = 0.5049526383273979, 0.49504736167260216, 1e-15, 1e-15

# %%
# plot spectral embedding of the generated stiefel sampels
flat_Vr_arr = np.concatenate([rob.flatten()[:, None] for rob in Vr_lst], axis=1)
flat_Vbar_arr = np.concatenate([rob.flatten()[:, None] for rob in Vbar_lst], axis=1)
rob_Vr_all = np.concatenate([rob.flatten()[:, None] for rob in stiefel_samples_Vr] + [flat_Vr_arr], axis=1)
rob_Vbar_all = np.concatenate([rob.flatten()[:, None] for rob in stiefel_samples_Vbar] + [flat_Vbar_arr], axis=1)

from sklearn.manifold import SpectralEmbedding
import matplotlib.pyplot as plt

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']


# Perform spectral embedding
embedder = SpectralEmbedding(n_components=2)
embedding_Vr = embedder.fit_transform(rob_Vr_all.T)
embedding_Vbar = embedder.fit_transform(rob_Vbar_all.T)

# Plot the embeddings
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.scatter(embedding_Vr[:-1, 0], embedding_Vr[:-1, 1], color='gray', s=1, label='Vr samples')
plt.scatter(embedding_Vr[-1, 0], embedding_Vr[-1, 1], color='purple', label='Vr nominal', marker='x', s=100)

for i in range(len(Vr_lst) - 1):
    plt.scatter(embedding_Vr[-i-2, 0], embedding_Vr[-i-2, 1], color=colors[i], label=f"Vr {names[i]}", marker='^')

plt.legend()
plt.title('Spectral Embedding of Vr samples')


plt.subplot(1, 2, 2)
plt.scatter(embedding_Vbar[:-1, 0], embedding_Vbar[:-1, 1], color='gray', s=1, label='Vbar samples')
plt.scatter(embedding_Vbar[-1, 0], embedding_Vbar[-1, 1], color='purple', label='Vbar nominal', marker='x', s=100)

for i in range(len(Vbar_lst) - 1):
    plt.scatter(embedding_Vbar[-i-2, 0], embedding_Vbar[-i-2, 1], color=colors[i], label=f"Vbar {names[i]}", marker='^')

plt.legend()
plt.title('Spectral Embedding of Vbar samples')
plt.show()

# %%
modelform = config['params']['modelform']

def rhs(t, state, operators, multi_indices, modelform, input_func=None):
    r"""Evaluate the right-hand side of the model by applying each operator
    and summing the results.

    This is the function :math:`\Ophat(\qhat, \u)`
    where the model can be written as one of the following:

    * :math:`\ddt\qhat(t) = \Ophat(\qhat(t), \u(t))` (continuous time)
    * :math:`\qhat_{j+1} = \Ophat(\qhat_j, \u_j)` (discrete time)
    * :math:`\widehat{\mathbf{g}} = \Ophat(\qhat, \u)` (steady state)

    Parameters
    ----------
    state : (r,) ndarray
        State vector.
    input_ : (m,) ndarray or None
        Input vector corresponding to the state.

    Returns
    -------
    evaluation : (r,) ndarray
        Evaluation of the right-hand side of the model.
    """
    state = np.atleast_1d(state)
    
    # print("State shape: ", state.shape)
    
    out = np.zeros(state.shape, dtype=float)
    # gs = gen_poly(state[:, None], p=2)  # Assuming gen_poly is designed for column vector input
    
    # print("Solving for regularization parameters: ", params['lambda1'], params['lambda2'], params['lambda3'])
    
    if 'L' in modelform:
        # print("adding A")
        out += operators['A'] @ state
    
    if 'Q' in modelform:
        # ssq = get_x_sq(state[:, None].T).T  # Assuming get_x_sq can handle the shape
        # out += operators['F'] @ ssq.flatten()
        # print("adding F")
        mask = ckron_indices(state.shape[0])
        out += (operators["F"] @ np.prod(state[mask], axis=1))
        
    if 'P' in modelform:
        gs = gen_poly(state[:, None], p=p, multi_indices=multi_indices)  # Assuming gen_poly is designed for column vector input
        out += (operators['P'] @ gs).flatten()
        
    if 'C' in modelform:
        out += operators['C'].flatten()
    
    return out

# %%
X_all_nominal_full = np.load("../examples/burgers/burgersFEniCSx_u_sol_all_RE100.npy")

# %%
X_all_nominal_full.shape
# Out:
# (5, 8000, 130)

# %%
T_end_index = int(T_end/dt)

# %%
# nominal s_rec_full

Vr = Vr_lst[-1]
Vbar = Vbar_lst[-1]


coord = np.linspace(0, 1, N)
# print("coord = ", coord.shape)
IC = np.array([initial_condition(c) for c in coord])
q0 = Vr.T @ (IC[:, None] - X_ref).flatten()

T_end_full = 8
time_domain_full = np.arange(0, T_end_full, dt)

train_size = Shat_py.shape[1]

multi_indices = generate_multi_indices_efficient(len(q0), p=p)


modelform = config['params']['modelform']
out_full = scipy.integrate.solve_ivp(
            rhs,  # Integrate this function
            [time_domain_full[0], time_domain_full[-1]],  # over this time interval
            q0,  # from this initial condition
            t_eval=time_domain_full,  # evaluated at these points
            args=[operators, multi_indices, modelform, None],  # additional arguments to rhs
            
        )

s_hat_full = out_full.y
poly_full = np.concatenate(polynomial_form(s_hat_full, p=p), axis=0)
Xi = Xi_lst[-1] # the nominal Xi
# print("Poly shape: ", poly_full.shape)

s_rec_full_nominal = X_ref + Vr @ s_hat_full + Vbar @ Xi @ poly_full


abs_error_full_nominal = np.abs(X_all_nominal_full[2].T - s_rec_full_nominal)
relative_error_testing_window_nominal = np.linalg.norm(X_all_nominal_full[2].T[:, T_end_index:] - s_rec_full_nominal[:, T_end_index:], 'fro') / np.linalg.norm(X_all_nominal_full[2].T[:, T_end_index:], 'fro')
relative_error_training_window_nominal = np.linalg.norm(X_all_nominal_full[2].T[:, :T_end_index] - s_rec_full_nominal[:, :T_end_index], 'fro') / np.linalg.norm(X_all_nominal_full[2].T[:, :T_end_index], 'fro')

# %%
import tqdm

N_samples = 1000
abs_error_full_lst = []
relative_error_testing_window_lst = []
relative_error_training_window_lst = []
s_rec_full_lst = []

for i in tqdm.tqdm(range(N_samples)):
    # # randomly choose 1 from stiefel_samples_Vr and 1 from stiefel_samples_Vbar
    # idx_Vr = np.random.randint(0, N_stiefel_samples)
    # idx_Vbar = np.random.randint(0, N_stiefel_samples)
    
    Vr_sample = stiefel_samples_Vr[i]
    Vbar_sample = stiefel_samples_Vbar[i]
    

    coord = np.linspace(0, 1, N)
    # print("coord = ", coord.shape)
    IC = np.array([initial_condition(c) for c in coord])
    q0 = Vr_sample.T @ (IC[:, None] - X_ref).flatten()
    
    T_end_full = 8
    time_domain_full = np.arange(0, T_end_full, dt)
    
    train_size = Shat_py.shape[1]

    multi_indices = generate_multi_indices_efficient(len(q0), p=p)
    

    modelform = config['params']['modelform']
    out_full = scipy.integrate.solve_ivp(
                rhs,  # Integrate this function
                [time_domain_full[0], time_domain_full[-1]],  # over this time interval
                q0,  # from this initial condition
                t_eval=time_domain_full,  # evaluated at these points
                args=[operators, multi_indices, modelform, None],  # additional arguments to rhs
                
            )
    
    s_hat_full = out_full.y
    poly_full = np.concatenate(polynomial_form(s_hat_full, p=p), axis=0)
    Xi = Xi_lst[-1] # the nominal Xi
    # print("Poly shape: ", poly_full.shape)

    s_rec_full = X_ref + Vr_sample @ s_hat_full + Vbar_sample @ Xi @ poly_full
    
    
    abs_error_full = np.abs(X_all_nominal_full[2].T - s_rec_full)
    relative_error_testing_window = np.linalg.norm(X_all_nominal_full[2].T[:, T_end_index:] - s_rec_full[:, T_end_index:], 'fro') / np.linalg.norm(X_all_nominal_full[2].T[:, T_end_index:], 'fro')
    relative_error_training_window = np.linalg.norm(X_all_nominal_full[2].T[:, :T_end_index] - s_rec_full[:, :T_end_index], 'fro') / np.linalg.norm(X_all_nominal_full[2].T[:, :T_end_index], 'fro')
    
    abs_error_full_lst.append(abs_error_full)
    relative_error_testing_window_lst.append(relative_error_testing_window)
    relative_error_training_window_lst.append(relative_error_training_window)
    s_rec_full_lst.append(s_rec_full)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 100%|██████████| 1000/1000 [00:11<00:00, 87.77it/s]

# %%
# mean relative error across the testing window
mean_relative_error = np.mean(relative_error_testing_window_lst)
std_relative_error = np.std(relative_error_testing_window_lst)
coeff_var = std_relative_error / mean_relative_error
print(f"Mean relative error: {mean_relative_error:.4%}")
print(f"Std relative error: {std_relative_error:.4%}")
print(f"Coefficient of variation: {coeff_var:.4%}")
# Out:
# Mean relative error: 7.2557%
# Std relative error: 0.0242%
# Coefficient of variation: 0.3334%

# %%
X_all_nominal.shape
# Out:
# (5, 2001, 130)

# %%
# coefficient of variation of s_rec_full
coeff_var_s_rec_full = np.std(s_rec_full_lst, axis=0) / (np.mean(s_rec_full_lst, axis=0))
std_s_rec_full = np.std(s_rec_full_lst, axis=0)
# Out:
# /tmp/ipykernel_3352666/2287357634.py:2: RuntimeWarning: invalid value encountered in divide
#   coeff_var_s_rec_full = np.std(s_rec_full_lst, axis=0) / (np.mean(s_rec_full_lst, axis=0))

# %%
#  mean reconstruction
mean_s_rec_full = np.mean(s_rec_full_lst, axis=0).T

# %%
# replace NaN with 0
coeff_var_s_rec_full = np.nan_to_num(coeff_var_s_rec_full)

# %%
# calculate 95% confidence interval
# confidence_interval = 1.96 * std_s_rec_full / np.sqrt(N_samples)
confidence_interval = 1.96 * std_s_rec_full

# %%
# plot the results side by side
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Assuming s_ref_all is a list of 2D numpy arrays
for i in range(1):
    fig, axs = plt.subplots(1, 3, figsize=(12, 6))
    XX, YY = np.meshgrid(np.linspace(0.0, T_end_full, int(mean_s_rec_full.shape[0])), np.linspace(0.0, 1.0, mean_s_rec_full.shape[1]))
    print("X = ", XX.shape)
    print("Y = ", YY.shape)
    print("s_ref_all[i] = ", mean_s_rec_full.shape)
    # s = ax.plot_surface(X, Y, s_ref_all[i].reshape(N, int(K+1)), cmap='viridis')
    
    c0 = axs[0].imshow(X_all_nominal_full[2].T, extent=[np.min(XX), np.max(XX), np.min(YY), np.max(YY)], origin='lower', aspect='auto')
    fig.colorbar(c0, ax=axs[0], orientation='vertical')
    axs[0].set_xlabel('t')
    axs[0].set_ylabel('x')
    axs[0].set_title(f'True state for IC $\mu$ = {mus[2]}')
    
    
    c1 = axs[1].imshow(mean_s_rec_full.T, extent=[np.min(XX), np.max(XX), np.min(YY), np.max(YY)], origin='lower', aspect='auto')
    fig.colorbar(c1, ax=axs[1], orientation='vertical')
    axs[1].set_xlabel('t')
    axs[1].set_ylabel('x')
    axs[1].set_title(f'Mean predicted state')
    
    c2 = axs[2].imshow(std_s_rec_full, extent=[np.min(XX), np.max(XX), np.min(YY), np.max(YY)], origin='lower', aspect='auto')
    fig.colorbar(c2, ax=axs[2], orientation='vertical')
    # c2 = axs[1].imshow(s_rec_all[i].reshape(N, int(K+1)), extent=[np.min(X), np.max(X), np.min(Y), np.max(Y)], origin='lower', aspect='auto')
    axs[2].set_xlabel('t')
    axs[2].set_ylabel('x')
    axs[2].set_title(f'Std predicted state')
    
    # use same colorbar for both plots, the range is determined by the maximum and minimum values of the two plots
    # vmin = np.min([np.min(coeff_var_s_rec_full[2]), np.min(coeff_var_s_rec_full)])
    # vmax = np.max([np.max(std_s_rec_full[2]), np.max(std_s_rec_full)])
    # c1.set_clim(vmin=vmin, vmax=vmax)
    # c2.set_clim(vmin=vmin, vmax=vmax)
    
    # fig.colorbar(c0, ax=axs, orientation='horizontal', fraction=0.05, pad=0.05)
    # fig.colorbar(c1, ax=axs, orientation='horizontal', fraction=0.05, pad=0.05)
    # fig.colorbar(c2, ax=axs, orientation='horizontal', fraction=0.05, pad=0.05)
    
    plt.suptitle(f"RE100, IC $\mu$ = {mus[2]}, r={r}, q={q_trunc}, p={p}")
    plt.tight_layout()  
    plt.show()
# Out:
# X =  (130, 8000)
# Y =  (130, 8000)
# s_ref_all[i] =  (8000, 130)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize


# plot 95% confidence interval of the solution
fig = plt.figure(figsize=(6, 6))
# ax = fig.add_subplot(111, projection='3d')
ax = fig.add_subplot(111)
upper_bound = mean_s_rec_full + confidence_interval.T
lower_bound = mean_s_rec_full - confidence_interval.T

XX, YY = np.meshgrid(np.linspace(0.0, T_end_full, int(s_rec_full_nominal.T.shape[0])), np.linspace(0.0, 1.0, s_rec_full_nominal.T.shape[1]))

# surf = ax.plot_surface(XX, YY, s_rec_full_nominal, cmap='viridis', alpha=0.7)

contour = ax.imshow(s_rec_full_nominal, extent=[np.min(XX), np.max(XX), np.min(YY), np.max(YY)], origin='lower', aspect='auto')
cbar = fig.colorbar(ScalarMappable(norm=Normalize(vmin=np.min(s_rec_full_nominal.T), vmax=np.max(s_rec_full_nominal.T)), cmap='viridis'), ax=ax, orientation='vertical', fraction=0.05, pad=0.05)
cbar.set_label('Mean Velocity')


# draw vertical plane at t=0.125, 0.375, 1,75
for t in [0.125, 0.375, 1.75]:
    ax.plot([t, t], [0, 1], [0, 0], color='red', linestyle='--')


ax.set_xlabel('t')
ax.set_ylabel('x')
# ax.set_zlabel('u')
ax.set_title(f'RE100, nominal model solution for IC $\mu$ = {mus[2]}, r={r}, q={q_trunc}, p={p}')
# Out:
# Text(0.5, 1.0, 'RE100, nominal model solution for IC $\\mu$ = 1, r=4, q=2, p=2')

# %%
mean_s_rec_full.shape
# Out:
# (8000, 130)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import numpy as np

# Example setup (you'll need to define mean_s_rec_full, lower_bound, and upper_bound appropriately)
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

for i, t in enumerate([0.125, 0.375, 1.75]):
    ax = axs[i]
    t_index = int(t / dt)  # Ensure dt is defined and properly calculated

    # Main plot
    x_values = np.linspace(0, 1, mean_s_rec_full.shape[1])
    nominal_line = s_rec_full_nominal[:, t_index]
    mean_line = mean_s_rec_full.T[:, t_index]
    true_line = X_all_nominal_full[2].T[:, t_index]
    lower_line = lower_bound.T[:, t_index]
    upper_line = upper_bound.T[:, t_index]
    
    ax.plot(x_values, mean_line, label='Mean', linestyle="--")
    ax.plot(x_values, true_line, label='True', linestyle="-.")
    ax.plot(x_values, nominal_line, label='Nominal', linestyle="dotted")
    ax.fill_between(x_values, lower_line, upper_line, alpha=1, label='95% CI', color='lavender')
    ax.set_title(f"t = {t}")
    ax.set_xlabel('x')
    ax.set_ylabel('u')
    ax.legend(loc="upper left")

    # Create an inset axis
    axins = inset_axes(ax, width="25%", height="25%", loc='center right')

    # Plot the same data on the inset
    axins.plot(x_values, mean_line, linestyle="--")
    axins.plot(x_values, true_line, linestyle="-.")
    axins.plot(x_values, nominal_line, linestyle="dotted")
    
    if np.allclose(lower_line, upper_line):
        print("Lower and upper bounds are the same")
        axins.plot(x_values, lower_line, color='lavender')
    else:
        print("Lower and upper bounds are different")
        axins.fill_between(x_values, lower_line, upper_line, color='lavender', alpha=1)

    # Zoom-in range for the x-axis
    focus_x_min, focus_x_max = 0.8, 0.81
    axins.set_xlim(focus_x_min, focus_x_max)
    axins.set_ylim(np.min(lower_line), np.max(upper_line))

    # Dynamically determine the y-range based on the focus area
    mask = (x_values >= focus_x_min) & (x_values <= focus_x_max)
    focus_y_min = min(np.min(lower_line[mask]), np.min(mean_line[mask]))
    focus_y_max = max(np.max(upper_line[mask]), np.max(mean_line[mask]))
    y_margin = (focus_y_max - focus_y_min) * 0.1  # Adjust margin
    axins.set_ylim(focus_y_min - y_margin, focus_y_max + y_margin)

    # Optionally remove tick labels to declutter
    axins.xaxis.set_tick_params(labelbottom=True)
    axins.yaxis.set_tick_params(labelleft=True)

# plt.tight_layout()
plt.suptitle(f"Confidence interval for 1000 samples of Vr and Vbar, RE100, IC $\mu$ = {mus[2]}, r={r}, q={q_trunc}, p={p}")
plt.show()
# Out:
# Lower and upper bounds are different
# Lower and upper bounds are different
# Lower and upper bounds are different

# %%
# lower bound
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')
lower_surf = ax.plot_surface(XX, YY, lower_bound.T, color='red', alpha=0.2)
lower_colorbar = fig.colorbar(ScalarMappable(norm=Normalize(vmin=np.min(lower_bound), vmax=np.max(lower_bound)), cmap='Reds'), ax=ax, shrink=0.5, aspect=5)
lower_colorbar.set_label('Lower Bound')
# upper bound
upper_surf = ax.plot_surface(XX, YY, upper_bound.T, color='blue', alpha=0.2)
upper_colorbar = fig.colorbar(ScalarMappable(norm=Normalize(vmin=np.min(upper_bound), vmax=np.max(upper_bound)), cmap='Blues'), ax=ax, shrink=0.5, aspect=5)
upper_colorbar.set_label('Upper Bound')
