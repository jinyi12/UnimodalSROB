# %%
from OpInf import *
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import json
import pickle

from scipy.io import loadmat
from operators import ckron, ckron_indices

import scienceplots
import adjustText
plt.style.use(["science", "no-latex", "grid"])

# %%
# load OpInfPoly_Results_Err_Analysis_vary_r

with open("OpInfPoly_Results_Err_Analysis_vary_r.pkl", "rb") as f:
    OpInfPoly_Results_Err_Analysis_vary_r = pickle.load(f)

regs_lst_poly_vary_r = OpInfPoly_Results_Err_Analysis_vary_r["regs_lst"]
reduced_state_error_poly_vary_r = OpInfPoly_Results_Err_Analysis_vary_r["errors"]
relative_error_training_vary_r = OpInfPoly_Results_Err_Analysis_vary_r["relative_error_training"]
relative_error_testing_vary_r = OpInfPoly_Results_Err_Analysis_vary_r["relative_error_testing"]
energy_lst_poly_vary_r = OpInfPoly_Results_Err_Analysis_vary_r["energy_lst"]

# # with open("OpInfPoly_energy_lst.pkl", "rb") as f:
#     energy_lst_poly = pickle.load(f)


# with open("OpInfPoly_Results_Err_Analysis_vary_r_p3.pkl", "rb") as f:
#     OpInfPoly_Results_Err_Analysis_vary_r_p3 = pickle.load(f)

# regs_lst_poly_vary_r_p3 = OpInfPoly_Results_Err_Analysis_vary_r_p3["regs_lst"]
# reduced_state_error_poly_vary_r_p3 = OpInfPoly_Results_Err_Analysis_vary_r_p3["errors"]
# relative_error_training_vary_r_p3 = OpInfPoly_Results_Err_Analysis_vary_r_p3["relative_error_training"]
# relative_error_testing_vary_r_p3 = OpInfPoly_Results_Err_Analysis_vary_r_p3["relative_error_testing"]
# energy_lst_poly_vary_r_p3 = OpInfPoly_Results_Err_Analysis_vary_r_p3["energy_lst"]

# %%
regs_lst_poly_vary_r
# Out:
# [[0.01, 1000.0, 1000.0],
#  [0.01, 69.51927961775604, 1000.0],
#  [0.01, 16.237767391887218, 10000000000.0],
#  [0.09999999999999999, 100.0, 1000000.0],
#  [0.09999999999999999, 100.0, 100000.0]]

# %%
# # update the regs_lst_poly_vary_r and relative_error_testing_vary_r, relative_error_training_vary_r
# regs_lst_poly_vary_r = np.array([[129.1549665014884, 200.00000000000003, 1389.4954943731373],
#     [10.0, 43.939705607607905, 27.825594022071257],
#     [10.0, 129.1549665014884, 1000000.0],
#     [10.0, 44.721359549995796, 10000000.0],
#     [100.0, 200.00000000000003, 10000000.0]
# ])

# relative_error_training_vary_r[1] = relative_error_training_vary_q[0]
# relative_error_testing_vary_r[1] = relative_error_testing_vary_q[0]

# relative_error_training_vary_r[2] = relative_error_training_vary_q_r12[0]
# relative_error_testing_vary_r[2] = relative_error_testing_vary_q_r12[0]

# with open("OpInfPoly_Results_Err_Analysis_vary_r.pkl", "wb") as f:
#     pickle.dump({
#         "regs_lst": regs_lst_poly_vary_r,
#         "errors": reduced_state_error_poly_vary_r,
#         "relative_error_training": relative_error_training_vary_r,
#         "relative_error_testing": relative_error_testing_vary_r
#     }, f)

# %%
# load OpInfPoly_Results_Err_Analysis_vary_q

with open("OpInfPoly_Results_Err_Analysis_vary_q.pkl", "rb") as f:
    OpInfPoly_Results_Err_Analysis_vary_q = pickle.load(f)
    
regs_lst_poly_vary_q = OpInfPoly_Results_Err_Analysis_vary_q["regs_lst_vary_q"]
reduced_state_error_poly_vary_q = OpInfPoly_Results_Err_Analysis_vary_q["errors"]
relative_error_training_vary_q = OpInfPoly_Results_Err_Analysis_vary_q["relative_error_training"]
relative_error_testing_vary_q = OpInfPoly_Results_Err_Analysis_vary_q["relative_error_testing"]
energy_lst_poly_vary_q = OpInfPoly_Results_Err_Analysis_vary_q["energy_lst"]


# with open("OpInfPoly_Results_Err_Analysis_vary_q_p3.pkl", "rb") as f:
#     OpInfPoly_Results_Err_Analysis_vary_q_p3 = pickle.load(f)

# regs_lst_poly_vary_q_p3 = OpInfPoly_Results_Err_Analysis_vary_q_p3["regs_lst_vary_q"]
# reduced_state_error_poly_vary_q_p3 = OpInfPoly_Results_Err_Analysis_vary_q_p3["errors"]
# relative_error_training_vary_q_p3 = OpInfPoly_Results_Err_Analysis_vary_q_p3["relative_error_training"]
# relative_error_testing_vary_q_p3 = OpInfPoly_Results_Err_Analysis_vary_q_p3["relative_error_testing"]
# energy_lst_poly_vary_q_p3 = OpInfPoly_Results_Err_Analysis_vary_q_p3["energy_lst"]

# %%
# # load OpInfPoly_Results_Err_Analysis_vary_q_MAM

# with open("OpInfPoly_Results_Err_Analysis_vary_q_MAM.pkl", "rb") as f:
#     OpInfPoly_Results_Err_Analysis_vary_q_MAM = pickle.load(f)

# regs_lst_poly_vary_q_MAM = OpInfPoly_Results_Err_Analysis_vary_q_MAM["regs_lst_vary_q"]
# reduced_state_error_poly_vary_q_MAM = OpInfPoly_Results_Err_Analysis_vary_q_MAM["errors"]
# relative_error_training_vary_q_MAM = OpInfPoly_Results_Err_Analysis_vary_q_MAM["relative_error_training"]
# relative_error_testing_vary_q_MAM = OpInfPoly_Results_Err_Analysis_vary_q_MAM["relative_error_testing"]
# energy_lst_poly_vary_q_MAM = OpInfPoly_Results_Err_Analysis_vary_q_MAM["energy_lst"]

# # # load OpInfPoly_Results_Err_Analysis_vary_q_r12

# # with open("OpInfPoly_Results_Err_Analysis_vary_q_r12.pkl", "rb") as f:
# #     OpInfPoly_Results_Err_Analysis_vary_q_r12 = pickle.load(f)

# # regs_lst_poly_vary_q_r12 = OpInfPoly_Results_Err_Analysis_vary_q_r12["regs_lst_vary_q"]
# # reduced_state_error_poly_vary_q_r12 = OpInfPoly_Results_Err_Analysis_vary_q_r12["errors"]
# # relative_error_training_vary_q_r12 = OpInfPoly_Results_Err_Analysis_vary_q_r12["relative_error_training"]
# # relative_error_testing_vary_q_r12 = OpInfPoly_Results_Err_Analysis_vary_q_r12["relative_error_testing"]
# # energy_lst_poly_vary_q_r12 = OpInfPoly_Results_Err_Analysis_vary_q_r12["energy_lst"]

# %%
with open("OpInfTest_Results_Err_Analysis.pkl", "rb") as f:
    OpInfTest_Results_Err_Analysis = pickle.load(f)

regs_lst_no_poly = OpInfTest_Results_Err_Analysis["regs_lst"]
reduced_state_error_no_poly = OpInfTest_Results_Err_Analysis["errors"]
relative_error_training_no_poly = OpInfTest_Results_Err_Analysis["relative_error_training"]
relative_error_testing_no_poly = OpInfTest_Results_Err_Analysis["relative_error_testing"]

# %%
print("Regs poly vary r: ", regs_lst_poly_vary_r)
print("errors poly vary r: ", reduced_state_error_poly_vary_r)
print("Relative Error Training poly vary r: ", relative_error_training_vary_r)
print("Relative Error Testing poly vary r: ", relative_error_testing_vary_r)
# Out:
# Regs poly vary r:  [[0.01, 1000.0, 1000.0], [0.01, 69.51927961775604, 1000.0], [0.01, 16.237767391887218, 10000000000.0], [0.09999999999999999, 100.0, 1000000.0], [0.09999999999999999, 100.0, 100000.0]]
# errors poly vary r:  [0.017351652083937928, 0.014233483130358928, 0.01090745401025427, 0.07635498842242557, 0.10325035334419509]
# Relative Error Training poly vary r:  [0.1728644919669552, 0.11678670763243625, 0.06026896425889289, 0.049574743474564274, 0.062100335136024934]
# Relative Error Testing poly vary r:  [0.2289869883140218, 0.14578639679349706, 0.033601861425478136, 0.10881636615451659, 0.10103770916822752]

# %%
print("Regs no poly: ", regs_lst_no_poly)
print("errors no poly: ", reduced_state_error_no_poly)
print("Relative Error Training no poly: ", relative_error_training_no_poly)
print("Relative Error Testing no poly: ", relative_error_testing_no_poly)
# Out:
# Regs no poly:  [[1.0, 359.38136638046257], [0.09999999999999999, 359.38136638046257], [0.09999999999999999, 46.41588833612778], [0.09999999999999999, 5.994842503189409], [0.09999999999999999, 5.994842503189409]]
# errors no poly:  [0.020774065724366828, 0.018190263627744063, 0.013349159009539847, 0.02696433332119201, 0.07105942472727984]
# Relative Error Training no poly:  [0.1874023473982558, 0.12851734120430228, 0.06374550579465416, 0.025277942974615292, 0.04289225816360835]
# Relative Error Testing no poly:  [0.10312696868602005, 0.0740307917328328, 0.03529347205091434, 0.02515355265445852, 0.032090922953600526]

# %%
q_trunc_lst = [2, 2**2, 2**3, 2**4, 2**5]
# max_idx_lst = [3, 5, 12, 32, 50]
max_idx_lst = [5, 8, 17, 38, 60]
# max_idx_lst = [5, 8, 17, 38]
err_tols = [1e-1, 5e-2, 1e-2, 1e-3, 1e-4]
# err_tols = [1e-1, 5e-2, 1e-2, 1e-3]

# %%
regs_lst_poly_vary_r
# Out:
# [[0.01, 1000.0, 1000.0],
#  [0.01, 69.51927961775604, 1000.0],
#  [0.01, 16.237767391887218, 10000000000.0],
#  [0.09999999999999999, 100.0, 1000000.0],
#  [0.09999999999999999, 100.0, 100000.0]]

# %%
regs_lst_poly_vary_q
# Out:
# [[0.01, 69.51927961775604, 1000.0],
#  [0.01, 69.51927961775604, 1000.0],
#  [0.01, 69.51927961775604, 1000.0],
#  [0.01, 69.51927961775604, 1000.0],
#  [0.01, 69.51927961775604, 1000.0]]

# %%
plt.figure(figsize=(6, 6))
# plot the relative error as a function of r and label each with the corresponding error tolerance
plt.plot(max_idx_lst, relative_error_testing_vary_r, marker='o', label='Relative Error Testing Window')
plt.plot(max_idx_lst, relative_error_training_vary_r, marker='o', label='Relative Error Training Window')
# plt.plot(max_idx_lst, relative_error_testing_vary_r[:-1], marker='o', label='Relative Error Testing Window')
# plt.plot(max_idx_lst, relative_error_training_vary_r[:-1], marker='o', label='Relative Error Training Window')

# plt.plot(max_idx_lst, relative_error_testing_vary_r_p3, marker='o', label='Relative Error Testing Window, p=3')
# plt.plot(max_idx_lst, relative_error_training_vary_r_p3, marker='o', label='Relative Error Training Window, p=3')

# mark the points with the corresponding snapshot energy
texts = []
for i, txt in enumerate(err_tols):
    texts.append(plt.annotate(f"$\epsilon(r)$: {txt:.1e}", (max_idx_lst[i], relative_error_testing_vary_r[i]), textcoords="offset points", xytext=(0,-10), ha='center'))

# adjustText.adjust_text(texts, force_pull=(0.7, 0.7))

plt.xlabel("r")
plt.ylabel("Relative State Error of Solution")
plt.title("Relative State Error of Solution vs. Truncated dimension r, q=2")
plt.xticks(max_idx_lst)
plt.legend()

# %%
print("Regs poly vary q: ", regs_lst_poly_vary_q)

fig, ax1 = plt.subplots(figsize=(6, 6))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# plot the relative error as a function of q_trunc and label each with the corresponding Energy
# ax1.plot(q_trunc_lst, relative_error_training_vary_q_MAM, marker='o', label='Training Window MAM', color=colors[0])
# ax1.plot(q_trunc_lst, relative_error_training_vary_q, marker='o', label='Training Window', color=colors[1])

# ax1.plot(q_trunc_lst, relative_error_testing_vary_q_MAM, marker='o', label='Testing Window MAM', linestyle='--', color=colors[0])
# ax1.plot(q_trunc_lst, relative_error_testing_vary_q, marker='o', label='Testing Window', linestyle='--', color=colors[1])


ax1.plot(q_trunc_lst, relative_error_testing_vary_q, marker='o', label='Testing Window')
ax1.plot(q_trunc_lst, relative_error_training_vary_q, marker='o', label='Training Window')

# # create a twin axis
# ax2 = ax1.twinx()
# ax2.plot(q_trunc_lst, energy_lst_poly_vary_q, marker='o', label='Snapshot Energy', linestyle='--')
# ax2.plot(q_trunc_lst, energy_lst_poly_vary_q_MAM, marker='o', label='Snapshot Energy MAM', linestyle='--')
# ax2.plot(q_trunc_lst, energy_lst_poly_vary_q_MAM_r2, marker='o', label='Snapshot Energy MAM r=2', linestyle='--')
# ax2.set_ylabel('Snapshot Energy', color='purple')

# # use a normal scale for the energy
# ax2.set_yscale('log')
# ax2.legend(loc='upper right')

# mark the points with the corresponding snapshot energy
texts = []
for i, txt in enumerate(energy_lst_poly_vary_q):
    texts.append(ax1.annotate(f"$\\varepsilon_r$: {txt:.2%}", (q_trunc_lst[i], relative_error_testing_vary_q[i]), textcoords="offset points", xytext=(0,5), ha='center'))

ax1.set_xlabel("q")
ax1.set_ylabel('Relative State Error of Solution')
# ax1.set_title("Relative State Error of Solution for r = 5, vs. q, Eigval err=5e-2")
ax1.set_title("Relative State Error of Solution for r = 8, vs. q, Eigval err=5e-2")
ax1.set_xticks(q_trunc_lst)
# put legend on optimal location
ax1.legend()
# set yscale depending on the data
# ax1.set_yscale('log')
# ax1.set_yticks([1e-1, 2e-1, 1.4])
# ax1.set_yticklabels(['0.1', '0.2', '1.4'])
fig.tight_layout()

# adjustText.adjust_text(texts, arrowprops=dict(arrowstyle="->", color='r', lw=0.5), ax=ax1, force_pull=(1, 1))
plt.show()
# Out:
# Regs poly vary q:  [[0.01, 69.51927961775604, 1000.0], [0.01, 69.51927961775604, 1000.0], [0.01, 69.51927961775604, 1000.0], [0.01, 69.51927961775604, 1000.0], [0.01, 69.51927961775604, 1000.0]]

# %%
relative_error_training_vary_q
# Out:
# [0.11678670763243625,
#  0.10969489935174108,
#  0.10396052843751603,
#  0.10370823258959698,
#  0.10370374255695833]

# %%
# print("Regs poly vary q: ", regs_lst_poly_vary_q_r12)

# fig, ax1 = plt.subplots(figsize=(6, 6))

# colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# # plot the relative error as a function of q_trunc and label each with the corresponding Energy
# ax1.plot(q_trunc_lst, relative_error_training_vary_q_r12, marker='o', label='Training Window r=12', color=colors[0])
# ax1.plot(q_trunc_lst, relative_error_testing_vary_q_r12, marker='o', label='Testing Window r=12', linestyle='--', color=colors[1])
# ax1.set_ylabel('Relative State Error of Solution')

# # # create a twin axis
# # ax2 = ax1.twinx()
# # ax2.plot(q_trunc_lst, energy_lst_poly_vary_q, marker='o', label='Snapshot Energy', linestyle='--')
# # ax2.plot(q_trunc_lst, energy_lst_poly_vary_q_MAM, marker='o', label='Snapshot Energy MAM', linestyle='--')
# # ax2.plot(q_trunc_lst, energy_lst_poly_vary_q_MAM_r2, marker='o', label='Snapshot Energy MAM r=2', linestyle='--')
# # ax2.set_ylabel('Snapshot Energy', color='purple')

# # # use a normal scale for the energy
# # ax2.set_yscale('log')
# # ax2.legend(loc='upper right')

# # mark the points with the corresponding snapshot energy
# texts = []
# for i, txt in enumerate(energy_lst_poly_vary_q_r12):
#     texts.append(ax1.annotate(f"$\\varepsilon_r$:{txt:.2%}", (q_trunc_lst[i], relative_error_testing_vary_q_r12[i]), textcoords="offset points", xytext=(0,-20), ha='center'))

# ax1.set_xlabel("q")
# ax1.set_title("Relative State Error of Solution for r = 12, vs. q, Eigval err=1e-2")
# ax1.set_xticks(q_trunc_lst)
# # put legend on optimal location
# ax1.legend()

# adjustText.adjust_text(texts, arrowprops=dict(arrowstyle="->", color='r', lw=1), force_pull=(1, 0.8))

# fig.tight_layout()


# plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(6, 6))

# plot the relative error as a function of q_trunc and label each with the corresponding Energy
ax1.plot(q_trunc_lst, relative_error_testing_vary_q, marker='o', label='Testing Window')
ax1.plot(q_trunc_lst, relative_error_training_vary_q, marker='o', label='Training Window')
ax1.set_ylabel('Relative Error', color='blue')

# create a twin axis
ax2 = ax1.twinx()
ax2.plot(q_trunc_lst, energy_lst_poly_vary_q, marker='o', color='red', label='Snapshot Energy')
ax2.set_ylabel('Snapshot Energy', color='red')

# use a normal scale for the energy
ax2.set_yscale('log')
ax2.legend()

# mark the points with the corresponding snapshot energy
for i, txt in enumerate(energy_lst_poly_vary_q):
    ax1.annotate(f"{txt:.3%}", (q_trunc_lst[i], relative_error_testing_vary_q[i]), textcoords="offset points", xytext=(0,5), ha='center')

ax1.set_xlabel("r")
# ax1.set_title("Relative Error of Solution for r = 5, vs. q, Eigval err=5e-2")
ax1.set_title("Relative Error of Solution for r = 8, vs. q, Eigval err=5e-2")
ax1.set_xticks(q_trunc_lst)
# put legend on optimal location
ax1.legend()
fig.tight_layout()


plt.show()

# %%
relative_error_training_no_poly
# Out:
# [0.1874023473982558,
#  0.12851734120430228,
#  0.06374550579465416,
#  0.025277942974615292,
#  0.04289225816360835]

# %%
relative_error_training_vary_r
# Out:
# [0.1728644919669552,
#  0.11678670763243625,
#  0.06026896425889289,
#  0.049574743474564274,
#  0.062100335136024934]

# %%
plt.figure(figsize=(6, 6))
# plot the relative error as a function of r and label each with the corresponding error tolerance
plt.plot(max_idx_lst, relative_error_testing_no_poly, marker='o', label='Relative Error Testing Window')
plt.plot(max_idx_lst, relative_error_training_no_poly, marker='o', label='Relative Error Training Window')

# mark the points with the corresponding snapshot energy
for i, txt in enumerate(err_tols):
    plt.annotate(f"$\epsilon(r)$: {txt:.1e}", (max_idx_lst[i], relative_error_testing_no_poly[i]), textcoords="offset points", xytext=(0,5), ha='center')

plt.xlabel("r")
plt.ylabel("Relative State Error of Solution")
plt.title("Relative State Error of Solution vs. Truncated dimension r, no poly")
plt.xticks(max_idx_lst)
plt.legend()
